# %%
import numpy as np

# %%
array = np.array([[10,20,30],
                  [40,50,60],
                  [70,80,90]])
print(array.ndim)#ndim retorna o numero de dimensões, aqui no caso são duas, sendo elas linhas e colunas
print(array.shape)#aqui é o elemento existente de cada dimensão, sendo 3 linhas e 3 colunas
array
# Out:
# 2
# (3, 3)
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
#buscar o elemento na linha 1 e na coluna 2
elemento = array[2,2]
elemento
#coluna 0,1 e 2 e linhas também, 60=linha 1 e coluna 2. 90 é linha 2 e coluna 2
# Out:
# np.int64(90)

# %%
#pegar dados da primeira linha
linha_0=array[0]
linha_0
# Out:
# array([10, 20, 30])

# %%
#acessando a coluna 1:
coluna_1= array[:,1]
coluna_1
# Out:
# array([20, 50, 80])

# %%
#fatiamento para obter um subarray
#linha p a 1 e coluna 1 e 2
subarray = array [0:2,1:3]
subarray
# Out:
# array([[20, 30],
#        [50, 60]])

# %%
mascara = array >50
mascara
# Out:
# array([[False, False, False],
#        [False, False,  True],
#        [ True,  True,  True]])

# %%
elementos_maiores_que_50 = array [mascara]
elementos_maiores_que_50
# Out:
# array([60, 70, 80, 90])

# %%
#modificando elemento na linha 1, coluna 1
array[1,1]=100
array
# Out:
# array([[ 10,  20,  30],
#        [ 40, 100,  60],
#        [ 70,  80,  90]])
