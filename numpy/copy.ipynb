# %% [markdown]
# Copy
# - Uma nova cópia do array é criada em memória.
# isso sginifica que as 2 matrizes são independetes de ambas.

# %% [markdown]
# View
#  - Não é criada em uma nova cópia na memória.
#  A view compatilha os mesmos dados que o array original.

# %%
import numpy as np
