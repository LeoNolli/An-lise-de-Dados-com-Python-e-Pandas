# %%
import numpy as np

# %%
array_ld = np.array([1,2,3,4,5])
array_ld.ndim
print(array_ld.shape)
array_ld
#lista de dados, como séries temporais ou coleções de valores
# Out:
# (5,)
# array([1, 2, 3, 4, 5])

# %%
array_2d=np.array([1,2,3,4,5])
print(array_2d.ndim)#numero de dimesões
print(array_2d.shape)#Formato do array
array_2d
#Marizes, tabelas de dados, imagnes em escala de cinza
# Out:
# 1
# (5,)
# array([1, 2, 3, 4, 5])
